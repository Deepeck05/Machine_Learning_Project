# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepeck05/Artificial_Inteligence_Project/blob/main/Machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.plot.scatter(x='TV',y='Sales')
plt.show()

# %%
df.plot.scatter(x='Radio',y='Sales')
plt.show()

# %%
df.plot.scatter(x='Newspaper',y='Sales')
plt.show()

# %%
#data preparation
x=df.drop('Sales',axis=1)
y=df['Sales']

# %%
#implelement linear regression method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#train test split function
from sklearn.model_selection import train_test_split
x_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,shuffle=True)
print(x_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
#imort linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)#.fit() is to train the model
print('MOdel training completed')
# Out:
# MOdel training completed

# %%
y_pred=lr.predict(X_test)
print(lr.coef_,lr.intercept_)
# Out:
# [0.05450927 0.10094536 0.00433665] 4.714126402214127

# %%
#visualing the coefecient
coef_df=pd.DataFrame(lr.coef_,x.columns,columns=['coef'])
coef_df
# Out:
#                coef
# TV         0.054509
# Radio      0.100945
# Newspaper  0.004337

# %%
from matplotlib import pyplot as plt
coef_df['coef'].plot(kind='line', figsize=(8, 4), title='Coefficient')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Predict on the test data
y_pred = lr.predict(X_test)
#error = |y_pred - y_test|. |3-3.1| = |-0.1| = 0.1

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 1.27
# Mean Squared Error (MSE): 2.91
# Root Mean Squared Error (RMSE): 1.71
# R-squared (R2): 0.91

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs. Predicted Sales')
plt.show()

# %%
import matplotlib.pyplot as plt

# Get the model's coefficients and intercept
intercept = lr.intercept_
coefficients = lr.coef_

# Create plots for each feature vs. Sales
features = ['TV', 'Radio', 'Newspaper']
for i, feature in enumerate(features):
    plt.figure(figsize=(8, 6))
    plt.scatter(X_test[feature], y_test, color='blue', label='Actual Sales')

    # Calculate predicted sales based on the current feature and the model's coefficients
    # This is an approximation for visualization purposes in 2D
    # The actual prediction uses all features
    predicted_sales_line = intercept + coefficients[i] * X_test[feature]
    plt.plot(X_test[feature], predicted_sales_line, color='red', label='Regression Line (based on this feature)')

    plt.xlabel(f'{feature} Advertising Budget')
    plt.ylabel('Sales')
    plt.title(f'Sales vs. {feature} Advertising Budget with Regression Line')
    plt.legend()
    plt.show()

# %%
# Calculate the residuals
residuals = y_test - y_pred

# Create the residual plot
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='--') # Add a horizontal line at zero
plt.xlabel('Predicted Sales')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
X = df[['TV', 'Radio', 'Newspaper']]    # input
y = df['Sales']                          # output

# ----------------------------
# 2. Train Linear Regression
# ----------------------------
model = LinearRegression()
model.fit(X, y)

# ----------------------------
# 3. Print Slope & Intercept
# ----------------------------
print("Slope (m1, m2, m3):", model.coef_)
print("Intercept (c):", model.intercept_)

predicted_sales = model.predict(new_data)

print("\nInput (New Data):")
print(x,y)

print("\nPredicted Sales:", predicted_sales[0])
# Out:
# Slope (m1, m2, m3): [0.05444578 0.10700123 0.00033566]
# Intercept (c): 4.625124078808653
#
# Input (New Data):
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64
#
# Predicted Sales: 15.426476682947506

# %%
X = df.drop('Sales',axis=1)# input features
y = df['Sales'] # output feature

for col in X.columns:
    df.plot(kind='scatter', x=col, y='Sales')
    plt.title(f'Scatter plot for {col} and Sales')
    plt.show()

# %%
plt.scatter(df['TV'], df['Sales'], label='TV')
plt.scatter(df['Radio'], df['Sales'], label='Radio')
plt.scatter(df['Newspaper'], df['Sales'], label='Newspaper')

plt.xlabel('Feature Values')
plt.ylabel('Sales')
plt.title('All Features vs Sales (One Graph)')
plt.legend()
plt.show()
